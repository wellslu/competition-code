# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import statistics as stat

# %% [markdown]
# # 合併三地時間和天氣

# %%
taipeimonth=pd.DataFrame({})
for j in tqdm_notebook(range(1,13)):
    for i in tqdm_notebook(range(1,32)):
        if j<10:
            try:
                if i<10:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\台北\466920-2017-0'+str(j)+'-0'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    taipeimonth=pd.concat([taipeimonth,df],ignore_index=True)
                else:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\台北\466920-2017-0'+str(j)+'-'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    taipeimonth=pd.concat([taipeimonth,df],ignore_index=True)
            except:
                1
        else:
            try:
                if i<10:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\台北\466920-2017-'+str(j)+'-0'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    taipeimonth=pd.concat([taipeimonth,df],ignore_index=True)
                else:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\台北\466920-2017-'+str(j)+'-'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    taipeimonth=pd.concat([taipeimonth,df],ignore_index=True)
            except:
                1

# %%
ilanmonth=pd.DataFrame({})
for j in tqdm_notebook(range(1,13)):
    for i in tqdm_notebook(range(1,32)):
        if j<10:
            try:
                if i<10:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\宜蘭\467080-2017-0'+str(j)+'-0'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    ilanmonth=pd.concat([ilanmonth,df],ignore_index=True)
                else:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\宜蘭\467080-2017-0'+str(j)+'-'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    ilanmonth=pd.concat([ilanmonth,df],ignore_index=True)
            except:
                1
        else:
            try:
                if i<10:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\宜蘭\467080-2017-'+str(j)+'-0'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    ilanmonth=pd.concat([ilanmonth,df],ignore_index=True)
                else:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\宜蘭\467080-2017-'+str(j)+'-'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    ilanmonth=pd.concat([ilanmonth,df],ignore_index=True)
            except:
                1

# %%
suaomonth=pd.DataFrame({})
for j in tqdm_notebook(range(1,13)):
    for i in tqdm_notebook(range(1,32)):
        if j<10:
            try:
                if i<10:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\蘇澳\467060-2017-0'+str(j)+'-0'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    suaomonth=pd.concat([suaomonth,df],ignore_index=True)
                else:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\蘇澳\467060-2017-0'+str(j)+'-'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    suaomonth=pd.concat([suaomonth,df],ignore_index=True)
            except:
                1
        else:
            try:
                if i<10:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\蘇澳\467060-2017-'+str(j)+'-0'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    suaomonth=pd.concat([suaomonth,df],ignore_index=True)
                else:
                    f=open(r'C:\Users\wells\OneDrive\Desktop\蘇澳\467060-2017-'+str(j)+'-'+str(i)+'.csv')
                    df=pd.read_csv(f)
                    df['date']='2017/'+str(j)+'/'+str(i)
                    suaomonth=pd.concat([suaomonth,df],ignore_index=True)
            except:
                1

# %%
taipeimonth.columns
# Out:
# Index(['ObsTime', 'StnPres', 'SeaPres', 'Temperature', 'Td dew point', 'RH',
#        'WS', 'WD', 'WSGust', 'WDGust', 'Precp', 'PrecpHour', 'SunShine',
#        'GloblRad', 'Visb', 'UVI', 'Cloud Amount', 'date'],
#       dtype='object')

# %%
taipeimonth.replace('T',0,inplace=True)
ilanmonth.replace('T',0,inplace=True)
suaomonth.replace('T',0,inplace=True)
taipeimonth['Precp']=taipeimonth['Precp'].astype(float)
ilanmonth['Precp']=ilanmonth['Precp'].astype(float)
suaomonth['Precp']=suaomonth['Precp'].astype(float)

# %%
month=pd.DataFrame({'Date':taipeimonth['date'],
                    'Hour':taipeimonth['ObsTime']-1,
                   '溫度':(taipeimonth['Temperature']+ilanmonth['Temperature']+suaomonth['Temperature'])/3,
                   '雨量':(taipeimonth['Precp']+ilanmonth['Precp']+suaomonth['Precp'])/3,
                   '濕度':(taipeimonth['RH']+ilanmonth['RH']+suaomonth['RH'])/3,
                   '風速':(taipeimonth['WS']+ilanmonth['WS']+suaomonth['WS'])/3})

# %% [markdown]
# # 加入違規件數

# %%
f=open(r'C:\Users\wells\OneDrive\Desktop\小時統計.csv',encoding='utf8')
vil_count=pd.read_csv(f)

# %%
month['違規件數']=vil_count['違規次數']

# %%
f=open(r'C:\Users\wells\OneDrive\Desktop\小時統計_new0818.csv',encoding='utf8')
vil_count=pd.read_csv(f)

# %%
vil_count
# Out:
#       Unnamed: 0                   時間  違規次數   車籍簡式車種列表  \
# 0              0  2017-01-01 00:00:00     2   {'1': 2}
# 1              1  2017-01-01 01:00:00    10  {'1': 10}
# 2              2  2017-01-01 02:00:00     4   {'1': 4}
# 3              3  2017-01-01 03:00:00     5   {'1': 5}
# 4              4  2017-01-01 04:00:00     3   {'1': 3}
# 5              5  2017-01-01 05:00:00     1   {'1': 1}
# 6              6  2017-01-01 06:00:00     4   {'1': 4}
# 7              7  2017-01-01 07:00:00     3   {'1': 3}
# 8              8  2017-01-01 08:00:00     6   {'1': 6}
# 9              9  2017-01-01 09:00:00    12  {'1': 12}
# 10            10  2017-01-01 10:00:00     2   {'1': 2}
# 11            11  2017-01-01 11:00:00     0         {}
# 12            12  2017-01-01 12:00:00     3   {'1': 3}
# 13            13  2017-01-01 13:00:00     1   {'1': 1}
# 14            14  2017-01-01 14:00:00    37  {'1': 37}
# 15            15  2017-01-01 15:00:00     8   {'1': 8}
# ...

# %% [markdown]
# # 加入車流量

# %%
f=open(r'C:\Users\wells\OneDrive\Desktop\car_num_everyday_hour.csv',encoding='utf8')
car_num=pd.read_csv(f)

# %%
car=[]
for h in tqdm_notebook(range(len(month))):
    i=month['Date'][h]
    j=month['Hour'][h]
    each_hour_carnum=car_num[car_num['Date'].isin([i])][car_num['Hour'].isin([j])].reset_index()
    try:
        car.append(each_hour_carnum['CarNum'][0])
    except:
        car.append(None)
# Out:
# ...
# C:\Users\wells\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
len(month1)
# Out:
# 8661

# %%
month['CarNum']=car

# %%
month
# Out:
#             Date  Hour         溫度        雨量         濕度        風速  違規件數  \
# 0       2017/1/1     6  19.033333  0.100000  86.333333  2.366667     4
# 1       2017/1/1     7  19.266667  0.233333  86.666667  2.466667     3
# 2       2017/1/1     8  20.166667  0.033333  85.000000  2.200000     6
# 3       2017/1/1     9  22.166667  0.000000  77.666667  1.600000    12
# 4       2017/1/1    10  23.700000  0.000000  68.666667  2.666667     2
# 5       2017/1/1    11  24.300000  0.000000  64.333333  3.400000     0
# 6       2017/1/1    12  24.533333  0.000000  63.000000  2.933333     3
# 7       2017/1/1    13  24.466667  0.000000  65.000000  3.233333     1
# 8       2017/1/1    14  24.200000  0.000000  64.666667  3.633333    37
# 9       2017/1/1    15  23.700000  0.000000  66.000000  3.300000     8
# 10      2017/1/1    16  22.833333  0.000000  66.666667  2.566667    10
# 11      2017/1/1    17  22.333333  0.000000  70.666667  2.433333     6
# ...

# %%
month1=month.dropna(axis=0,how='any').reset_index(drop=True)

# %%
month1['違規率']=round(month1['違規件數']/month1['CarNum'],4)*100

# %%
max(month1['違規率'])
# Out:
# 1300.0

# %%
month1.corr()
# Out:
#             Hour        溫度        雨量        濕度        風速      違規件數    CarNum  \
# Hour    1.000000  0.051778  0.055185 -0.104302  0.123427  0.049699  0.473754
# 溫度      0.051778  1.000000 -0.046339 -0.276168 -0.033937  0.142473  0.219517
# 雨量      0.055185 -0.046339  1.000000  0.300968  0.146354 -0.056922 -0.006004
# 濕度     -0.104302 -0.276168  0.300968  1.000000 -0.214630 -0.114714 -0.406604
# 風速      0.123427 -0.033937  0.146354 -0.214630  1.000000 -0.025751  0.275780
# 違規件數    0.049699  0.142473 -0.056922 -0.114714 -0.025751  1.000000  0.033335
# CarNum  0.473754  0.219517 -0.006004 -0.406604  0.275780  0.033335  1.000000
# 違規率    -0.069456  0.019955  0.001465  0.041387  0.024423  0.034790 -0.086781
#
#              違規率
# Hour   -0.069456
# 溫度      0.019955
# 雨量      0.001465
# 濕度      0.041387
# 風速      0.024423
# 違規件數    0.034790
# CarNum -0.086781
# 違規率     1.000000

# %% [markdown]
# # 違規率<100

# %%
month2=month1

# %%
month2=month2.loc[month2['違規率']<100]

# %%
x=month2['雨量']
y=month2['違規率']
x=x.values.reshape(8626,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('rain')
plt.ylabel('rate')
# Out:
# Text(0, 0.5, 'rate')

# %%
x=month2['溫度']
y=month2['違規率']
x=x.values.reshape(8626,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('temperature')
plt.ylabel('rate')
# Out:
# Text(0, 0.5, 'rate')

# %% [markdown]
# # 車流量>100

# %%
month22=month2

# %%
month22=month22.loc[month22['CarNum']>100]

# %%
x=month22['雨量']
y=month22['違規率']
x=x.values.reshape(8611,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('rain')
plt.ylabel('rate')
# Out:
# Text(0, 0.5, 'rate')

# %%
x=month22['溫度']
y=month22['違規率']
x=x.values.reshape(8611,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('temperature')
plt.ylabel('rate')
# Out:
# Text(0, 0.5, 'rate')

# %% [markdown]
# # 車流量>1000

# %%
month21=month2

# %%
month21=month21.loc[month21['CarNum']>1000]

# %%
x=month21['雨量']
y=month21['違規率']
x=x.values.reshape(7277,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('rain')
plt.ylabel('rate')
# Out:
# Text(0, 0.5, 'rate')

# %%
x=month21['溫度']
y=month21['違規率']
x=x.values.reshape(7277,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('temperature')
plt.ylabel('rate')
# Out:
# Text(0, 0.5, 'rate')

# %%
a=0
for i in month2['CarNum']:
    if i<1000:
        a+=1

# %%
month3=month2
for i in month3['CarNum']:
    if i<=1000:
        month3['CarNum'].replace(i,None,inplace=True)

# %%
month3=month3.dropna(axis=0,how='any').reset_index(drop=True)

# %%
x=month3['溫度']
y=month3['違規率']
plt.scatter(x,y)
plt.show()

# %%
test=month1.loc[month1['違規件數']>100]

# %%
max(month1['雨量'])
# Out:
# 33.4

# %%
month_f=month1.loc[month1['違規率']<100]

# %%
car=[]
accd=[]
perc=[]
for i in range(0,11700,300):
    t=month_f.loc[month_f['CarNum']<=i+300]
    t=t.loc[t['CarNum']>i]
    try:
        car.append(i+300)
        accd.append(stat.mean(t['違規件數']))
        perc.append(stat.mean(t['違規率']))
    except:
        accd.append(0)
        perc.append(0)

# %%
test=pd.DataFrame({'car':car,
                  'accd':accd,
                  'perc':perc})

# %%
test.corr()
# Out:
#            car      accd      perc
# car   1.000000  0.177151 -0.676794
# accd  0.177151  1.000000  0.038578
# perc -0.676794  0.038578  1.000000

# %%
x=test['car']
y=test['perc']
x=x.values.reshape(39,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('car')
plt.ylabel('rate')
# Out:
# Text(0, 0.5, 'rate')

# %%
rain=[]
accd=[]
perc=[]
for i in range(0,34):
    t=month_f.loc[month_f['雨量']<=(i+1)]
    t=t.loc[t['雨量']>i]
    try:
        rain.append((i*2+1)/2)
        accd.append(stat.mean(t['違規件數']))
        perc.append(stat.mean(t['違規率']))
    except:
        accd.append(0)
        perc.append(0)
test=pd.DataFrame({'rain':rain,
                  'accd':accd,
                  'perc':perc})

# %%
test.loc[test['perc']>0].corr()
# Out:
#           rain      accd      perc
# rain  1.000000  0.701716 -0.136376
# accd  0.701716  1.000000  0.282191
# perc -0.136376  0.282191  1.000000

# %%
test.loc[test['perc']>0].to_csv(r'C:\Users\wells\OneDrive\Desktop\rain.csv',encoding='utf_8_sig')

# %%
x=test.loc[test['perc']>0]['rain']
y=test.loc[test['perc']>0]['accd']
x=x.values.reshape(25,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('rain')
plt.ylabel('accd')
# Out:
# Text(0, 0.5, 'accd')

# %%
temp=[]
accd=[]
perc=[]
for i in range(54,175):
    t=month_f.loc[month_f['溫度']<=(i+1)/5]
    t=t.loc[t['溫度']>i/5]
    try:
        temp.append(i/5)
        accd.append(stat.mean(t['違規件數']))
        perc.append(stat.mean(t['違規率']))
    except:
        accd.append(0)
        perc.append(0)
test=pd.DataFrame({'temp':temp,
                  'accd':accd,
                  'perc':perc})

# %%
test.corr()
# Out:
#           temp      accd      perc
# temp  1.000000  0.497056 -0.043727
# accd  0.497056  1.000000  0.172719
# perc -0.043727  0.172719  1.000000

# %%
test.to_csv(r'C:\Users\wells\OneDrive\Desktop\temp.csv',encoding='utf_8_sig')

# %%
x=test['temp']
y=test['accd']
x=x.values.reshape(121,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('temp')
plt.ylabel('accd')
# Out:
# Text(0, 0.5, 'accd')

# %%
wet=[]
accd=[]
perc=[]
for i in range(18,50):
    t=month_f.loc[month_f['濕度']<(i+1)*2]
    t=t.loc[t['濕度']>=i*2]
    try:
        wet.append(i*2)
        accd.append(stat.mean(t['違規件數']))
        perc.append(stat.mean(t['違規率']))
    except:
        accd.append(0)
        perc.append(0)
test=pd.DataFrame({'wet':wet,
                  'accd':accd,
                  'perc':perc})

# %%
max(month_f['濕度'])
# Out:
# 99.66666666666667

# %%
test.corr()
# Out:
#            wet      accd      perc
# wet   1.000000 -0.634889  0.546143
# accd -0.634889  1.000000  0.119199
# perc  0.546143  0.119199  1.000000

# %%
test.to_csv(r'C:\Users\wells\OneDrive\Desktop\wet.csv',encoding='utf_8_sig')

# %%
x=test['wet']
y=test['perc']
x=x.values.reshape(32,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('wet')
plt.ylabel('perc')
# Out:
# Text(0, 0.5, 'perc')

# %%
x=test['wet']
y=test['accd']
x=x.values.reshape(32,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('wet')
plt.ylabel('accd')
# Out:
# Text(0, 0.5, 'accd')

# %%
wind=[]
accd=[]
perc=[]
for i in range(0,44):
    t=month_f.loc[month_f['風速']<=(i+1)/2.5]
    t=t.loc[t['風速']>i/2.5]
    try:
        wind.append(i/2.5)
        accd.append(stat.mean(t['違規件數']))
        perc.append(stat.mean(t['違規率']))
    except:
        accd.append(0)
        perc.append(0)
test=pd.DataFrame({'wind':wind,
                  'accd':accd,
                  'perc':perc})

# %%
test[test['accd']>0].corr()
# Out:
#           wind      accd      perc
# wind  1.000000  0.539912  0.257279
# accd  0.539912  1.000000  0.626130
# perc  0.257279  0.626130  1.000000

# %%
test[test['accd']>0].to_csv(r'C:\Users\wells\OneDrive\Desktop\wind.csv',encoding='utf_8_sig')

# %%
x=test[test['accd']>0]['wind']
y=test[test['accd']>0]['accd']
x=x.values.reshape(25,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('wind')
plt.ylabel('accd')
# Out:
# Text(0, 0.5, 'accd')

# %%
rain_m=0.70172/9.04102*1.75202

# %%
temp_m=0.49706/7.01475*1.12277

# %%
wet_m=-0.63489/18.76166*1.0945

# %%
wind_m=0.53991/4.27882*1.15337

# %%
print(rain_m,temp_m,wet_m,wind_m)
# Out:
# 0.13598327117957928 0.07955865229694573 -0.03703761314297349 0.1455345157543435

# %%
def new_fun(aa):
    aa['t']=0.136*aa['雨量']+0.08*aa['溫度']+(-0.037)*aa['濕度']+0.1455*aa['風速']
    return aa

# %%
month_t=month_f.apply(new_fun,axis=1)

# %%
month_t.rename(columns={'溫度':'temp','雨量':'rain','濕度':'wet','風速':'wind','違規件數':'accd','違規率':'perc'},inplace=True)

# %%
month_t.to_csv(r'C:\Users\wells\OneDrive\Desktop\t_grade.csv',encoding='utf_8_sig')

# %%
t=[]
accd=[]
perc=[]
for i in range(-20,37):
    f=month_t.loc[month_t['t']<=(i+1)/10]
    f=f.loc[f['t']>i/10]
    try:
        t.append(i/10)
        accd.append(stat.mean(f['accd']))
        perc.append(stat.mean(f['perc']))
    except:
        accd.append(0)
        perc.append(0)
test=pd.DataFrame({'t':t,
                  'accd':accd,
                  'perc':perc})

# %%
test[test['accd']>0].corr()
# Out:
#              t      accd      perc
# t     1.000000  0.755615 -0.069829
# accd  0.755615  1.000000  0.295647
# perc -0.069829  0.295647  1.000000

# %%
test[test['accd']>0].to_csv(r'C:\Users\wells\OneDrive\Desktop\t_grade1.csv',encoding='utf_8_sig')

# %%
x=test[test['accd']>0]['t']
y=test[test['accd']>0]['accd']
x=x.values.reshape(46,1)
regr = LinearRegression()
regr.fit(x, y)

plt.scatter(x, y)
plt.plot(x, regr.predict(x),'r')
plt.xlabel('VR')
plt.ylabel('accd')
# Out:
# Text(0, 0.5, 'accd')

# %%
month_t.to_csv(r'C:\Users\wells\OneDrive\Desktop\t_grade.csv',encoding='utf_8_sig')

# %%
month.to_csv(r'C:\Users\wells\OneDrive\Desktop\氣溫車流.csv',encoding='utf_8_sig')

# %%
month_t['Date']=pd.to_datetime(month_t['Date'])

# %%
month_t.groupby('Date').sum().to_csv(r'C:\Users\wells\OneDrive\Desktop\t_grade2.csv',encoding='utf_8_sig')

# %%
month_t['month']=month_t['Date'].dt.month

# %%
month_t.groupby('month').sum().to_csv(r'C:\Users\wells\OneDrive\Desktop\t_grade3.csv',encoding='utf_8_sig')

# %%
month_t.groupby('Date').sum().reset_index()
# Out:
#           Date  Hour        temp       rain          wet       wind  accd  \
# 0   2017-01-01   238  375.333333   0.366667  1236.666667  41.033333   120
# 1   2017-01-02   261  397.300000   0.000000  1336.666667  35.866667    92
# 2   2017-01-03   276  491.400000  19.100000  2083.000000  65.600000    68
# 3   2017-01-04   276  534.566667   0.800000  1907.666667  59.700000    92
# 4   2017-01-05   276  532.200000   0.000000  1900.333333  33.800000    64
# 5   2017-01-06   276  524.500000   5.333333  2009.666667  37.633333    84
# 6   2017-01-07   276  542.866667   0.200000  1959.333333  33.600000    70
# 7   2017-01-08   276  485.466667   0.866667  1972.666667  64.166667   105
# 8   2017-01-09   276  412.600000   2.200000  1861.000000  69.100000   135
# 9   2017-01-10   276  432.666667   0.000000  1714.333333  65.733333   136
# 10  2017-01-11   276  461.533333   1.000000  1888.666667  63.466667   104
# 11  2017-01-12   276  483.800000   0.533333  1984.333333  61.066667    88
# ...

# %%
x=month_t.groupby('month').sum().reset_index()['month']
y=month_t.groupby('month').sum().reset_index()['accd']

plt.scatter(x, y)
plt.xlabel('month')
plt.ylabel('accd')
# Out:
# Text(0, 0.5, 'accd')

# %%
month_t.groupby('Hour').sum().reset_index()
# Out:
#     Hour         temp        rain           wet         wind  accd     CarNum  \
# 0      0  7781.500000  117.233333  28110.333333   694.733333  1185   464595.0
# 1      1  7596.233333  108.400000  27666.333333   654.333333  1230   277960.0
# 2      2  7540.066667  117.200000  27783.333333   647.466667  1150   208345.0
# 3      3  7493.200000  112.800000  27862.000000   657.433333  1080   204113.0
# 4      4  7496.066667   99.566667  28103.333333   657.866667   890   284097.0
# 5      5  7720.066667  110.566667  28864.000000   672.233333   876   569128.0
# 6      6  8129.500000  116.433333  29423.666667   656.700000   971  1326301.0
# 7      7  8502.500000  100.500000  28408.000000   663.200000   692  2521291.0
# 8      8  8839.666667  101.966667  27312.000000   780.133333   965  2361291.0
# 9      9  9103.366667   90.600000  26462.333333   919.800000  1223  2509022.0
# 10    10  9264.000000   77.466667  25964.666667  1038.766667  1143  2727327.0
# ...

# %%
x=month_t.groupby('Hour').sum().reset_index()['Hour']
y=month_t.groupby('Hour').sum().reset_index()['t']

plt.scatter(x, y)
plt.xlabel('Hour')
plt.ylabel('vr')
# Out:
# Text(0, 0.5, 'vr')
