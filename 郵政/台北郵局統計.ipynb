# %%
import pandas as pd
n=open('D:/wells/初賽資料/ACCS1.csv')
b=['交寄局號',
    '是否特約',
    '頁碼',
    '段號',
    '郵件狀態',
    '交寄日期',
    '交寄時間',
    '責任局號',
    '部門別',
    '收件人付費狀態',
    '總件數',
    '基本郵件種類',
    '細分類',
    '郵寄內容',
    '是否代收貨價',
    '0無1普通回執2掛號回執3限時掛號回執',
    '是否存證',
    '針對大宗郵件收寄處理方式',
    '是否附寄',
    '附寄郵件種類',
    '是否保價',
    '是否掛號',
    '速度別',
    '報值種類',
    '0國內1國際',
    '特約戶繳費方式',
    '郵件種類名稱',
    '寄達遞郵遞區號',
    '計費方式',
    '本頁件數',
    '本頁重量',
    '本段件數',
    '掛號號碼起號',
    '掛號號碼迄號',
    '便利箱袋種類',
    '箱袋使用狀態',
    '收寄年月',
    '收寄月份']
data = pd.read_csv(n,names=b, iterator=True, sep=',', chunksize=10000,low_memory=False)

# %%
c=['100042','100106','100126','100129','100052','100028','100123','100105','100073','100077','100083','100116','100059','100086','100125',
'100050','100061','100047','100021','100010','100011',
'100096','100082','100117','100023','100024','100032','100057','100007','100022','100108','100043','100053','100026','100044','100090','100091',
'100014','100058','100072','100100','100107','100110','100115','100120','100177','100001','100006','100008','100071','100012','100015','100020','100025','100084','100064','100092','100030','100033','100005','100013','100000','100039',
'100027','100104','100121','100192','100065','100009','100017','100037','100046','100068','100112','100034','100055','100067','100122',
'100158','100150','100152','100155','100156','100157','100149','100159','100160','100151','100153','100154','100148',
'100093','100111','100171','100173','100178','100183','100075','100029','100172','100170','100097','100176','100179',
'100142','100134','100135','100137','100138','100139','100140','100141','100124','100143','100144','100145','100146','100133','100136','100131','100147',
'100118','100056','100018','100048','100045','100081','100101','100036','100087',
'100128','100054','100099','100049','100051','100078','100080','100109',
'100169','100165','100166','100168','100164','100161','100162','100191','100167',
'100095','100004','100070','100074','100003','100035','100079','100002','100031']

# %%
data1=data.get_chunk(1000000)

data1=data1[data1['交寄局號'].isin(c)]
data1=data1.reset_index(drop=True)

data2=data.get_chunk(1000000)

data2=data2[data2['交寄局號'].isin(c)]
data2=data2.reset_index(drop=True)

data3=data.get_chunk(1000000)

data3=data3[data3['交寄局號'].isin(c)]
data3=data3.reset_index(drop=True)

data4=data.get_chunk(1000000)

data4=data4[data4['交寄局號'].isin(c)]
data4=data4.reset_index(drop=True)

data5=data.get_chunk(1000000)

data5=data5[data5['交寄局號'].isin(c)]
data5=data5.reset_index(drop=True)

data6=data.get_chunk(1000000)

data6=data6[data6['交寄局號'].isin(c)]
data6=data6.reset_index(drop=True)

data7=data.get_chunk(1000000)

data7=data7[data7['交寄局號'].isin(c)]
data7=data7.reset_index(drop=True)

data8=data.get_chunk(1000000)

data8=data8[data8['交寄局號'].isin(c)]
data8=data8.reset_index(drop=True)

data9=data.get_chunk(1000000)

data9=data9[data9['交寄局號'].isin(c)]
data9=data9.reset_index(drop=True)

data10=data.get_chunk(1000000)

data10=data10[data10['交寄局號'].isin(c)]
data10=data10.reset_index(drop=True)

data11=data.get_chunk(1000000)

data11=data11[data11['交寄局號'].isin(c)]
data11=data11.reset_index(drop=True)

data12=data.get_chunk(1000000)

data12=data12[data12['交寄局號'].isin(c)]
data12=data12.reset_index(drop=True)

data13=data.get_chunk(1000000)

data13=data13[data13['交寄局號'].isin(c)]
data13=data13.reset_index(drop=True)

data14=data.get_chunk(1000000)

data14=data14[data14['交寄局號'].isin(c)]
data14=data14.reset_index(drop=True)

data15=data.get_chunk(1000000)

data15=data15[data15['交寄局號'].isin(c)]
data15=data15.reset_index(drop=True)

data16=data.get_chunk(1000000)

data16=data16[data16['交寄局號'].isin(c)]
data16=data16.reset_index(drop=True)

data17=data.get_chunk(1000000)

data17=data17[data17['交寄局號'].isin(c)]
data17=data17.reset_index(drop=True)

data18=data.get_chunk(1000000)

data18=data18[data18['交寄局號'].isin(c)]
data18=data18.reset_index(drop=True)

data19=data.get_chunk(1000000)

data19=data19[data19['交寄局號'].isin(c)]
data19=data19.reset_index(drop=True)

data20=data.get_chunk(1000000)

data20=data20[data20['交寄局號'].isin(c)]
data20=data20.reset_index(drop=True)

data21=data.get_chunk(1000000)

data21=data21[data21['交寄局號'].isin(c)]
data21=data21.reset_index(drop=True)

data22=data.get_chunk(1000000)

data22=data22[data22['交寄局號'].isin(c)]
data22=data22.reset_index(drop=True)

data23=data.get_chunk(1000000)

data23=data23[data23['交寄局號'].isin(c)]
data23=data23.reset_index(drop=True)

data24=data.get_chunk(1000000)

data24=data24[data24['交寄局號'].isin(c)]
data24=data24.reset_index(drop=True)

data25=data.get_chunk(1000000)

data25=data25[data25['交寄局號'].isin(c)]
data25=data25.reset_index(drop=True)

data26=data.get_chunk(1000000)

data26=data26[data26['交寄局號'].isin(c)]
data26=data26.reset_index(drop=True)

data27=data.get_chunk(1000000)

data27=data27[data27['交寄局號'].isin(c)]
data27=data27.reset_index(drop=True)

data28=data.get_chunk(1000000)

data28=data28[data28['交寄局號'].isin(c)]
data28=data28.reset_index(drop=True)

# %%
dataT1=pd.concat([data1,data2,data3,data4,data5,data6,data7],ignore_index=True)

# %%
dataT2=pd.concat([data8,data9,data10,data11,data12,data13,data14],ignore_index=True)

# %%
dataT3=pd.concat([data15,data16,data17,data18,data19,data20,data21],ignore_index=True)

# %%
dataT4=pd.concat([data22,data23,data24,data25,data26,data27,data28],ignore_index=True)

# %%
d=[ '是否特約',
    '頁碼',
    '段號',
    '郵件狀態',
    '部門別',
    '收件人付費狀態',
    '基本郵件種類',
    '細分類',
    '郵寄內容',
    '是否代收貨價',
    '0無1普通回執2掛號回執3限時掛號回執',
    '是否存證',
    '針對大宗郵件收寄處理方式',
    '是否附寄',
    '附寄郵件種類',
    '是否保價',
    '是否掛號',
    '速度別',
    '報值種類',
    '0國內1國際',
    '特約戶繳費方式',
    '郵件種類名稱',
    '計費方式',
    '本頁件數',
    '本頁重量',
    '本段件數',
    '掛號號碼起號',
    '掛號號碼迄號',
    '便利箱袋種類',
    '箱袋使用狀態']
for i in d:
    dataT1=dataT1.drop(i,axis=1)
    dataT2=dataT2.drop(i,axis=1)
    dataT3=dataT3.drop(i,axis=1)
    dataT4=dataT4.drop(i,axis=1)

# %%
sl=0
dt=0
da=0
cc=0
cs=0
nh=0
ws=0
bt=0
ss=0
xi=0
nk=0
wh=0

# %%
for i in dataT1['交寄局號']:
    if i in [100042,100106,100126,100129,100052,100028,100123,100105,100073,100077,100083,100116,100059,100086,100125]:
        sl=sl+1
    elif i in [100050,100061,100047,100021,100010,100011]:
        dt=dt+1
    elif i in [100096,100082,100117,100023,100024,100032,100057,100007,100022,100108,100043,100053,100026,100044,100090,100091]:
        da=da+1
    elif i in [100014,100058,100072,100100,100107,100110,100115,100120,100177,100001,100006,100008,100071,100012,100015,100020,100025,100084,100064,100092,100030,100033,100005,100013,100000,100039]:
        cc=cc+1
    elif i in [100027,100104,100121,100192,100065,100009,100017,100037,100046,100068,100112,100034,100055,100067,100122]:
        cs=cs+1
    elif i in [100158,100150,100152,100155,100156,100157,100149,100159,100160,100151,100153,100154,100148]:
        nh=nh+1
    elif i in [100093,100111,100171,100173,100178,100183,100075,100029,100172,100170,100097,100176,100179]:
        ws=ws+1
    elif i in [100142,100134,100135,100137,100138,100139,100140,100141,100124,100143,100144,100145,100146,100133,100136,100131,100147]:
        bt=bt+1
    elif i in [100118,100056,100018,100048,100045,100081,100101,100036,100087]:
        ss=ss+1
    elif i in [100128,100054,100099,100049,100051,100078,100080,100109]:
        xi=xi+1
    elif i in [100169,100165,100166,100168,100164,100161,100162,100191,100167]:
        nk=nk+1
    elif i in [100095,100004,100070,100074,100003,100035,100079,100002,100031]:
        wh=wh+1

# %%
for i in dataT2['交寄局號']:
    if i in [100042,100106,100126,100129,100052,100028,100123,100105,100073,100077,100083,100116,100059,100086,100125]:
        sl=sl+1
    elif i in [100050,100061,100047,100021,100010,100011]:
        dt=dt+1
    elif i in [100096,100082,100117,100023,100024,100032,100057,100007,100022,100108,100043,100053,100026,100044,100090,100091]:
        da=da+1
    elif i in [100014,100058,100072,100100,100107,100110,100115,100120,100177,100001,100006,100008,100071,100012,100015,100020,100025,100084,100064,100092,100030,100033,100005,100013,100000,100039]:
        cc=cc+1
    elif i in [100027,100104,100121,100192,100065,100009,100017,100037,100046,100068,100112,100034,100055,100067,100122]:
        cs=cs+1
    elif i in [100158,100150,100152,100155,100156,100157,100149,100159,100160,100151,100153,100154,100148]:
        nh=nh+1
    elif i in [100093,100111,100171,100173,100178,100183,100075,100029,100172,100170,100097,100176,100179]:
        ws=ws+1
    elif i in [100142,100134,100135,100137,100138,100139,100140,100141,100124,100143,100144,100145,100146,100133,100136,100131,100147]:
        bt=bt+1
    elif i in [100118,100056,100018,100048,100045,100081,100101,100036,100087]:
        ss=ss+1
    elif i in [100128,100054,100099,100049,100051,100078,100080,100109]:
        xi=xi+1
    elif i in [100169,100165,100166,100168,100164,100161,100162,100191,100167]:
        nk=nk+1
    elif i in [100095,100004,100070,100074,100003,100035,100079,100002,100031]:
        wh=wh+1

# %%
for i in dataT3['交寄局號']:
    if i in [100042,100106,100126,100129,100052,100028,100123,100105,100073,100077,100083,100116,100059,100086,100125]:
        sl=sl+1
    elif i in [100050,100061,100047,100021,100010,100011]:
        dt=dt+1
    elif i in [100096,100082,100117,100023,100024,100032,100057,100007,100022,100108,100043,100053,100026,100044,100090,100091]:
        da=da+1
    elif i in [100014,100058,100072,100100,100107,100110,100115,100120,100177,100001,100006,100008,100071,100012,100015,100020,100025,100084,100064,100092,100030,100033,100005,100013,100000,100039]:
        cc=cc+1
    elif i in [100027,100104,100121,100192,100065,100009,100017,100037,100046,100068,100112,100034,100055,100067,100122]:
        cs=cs+1
    elif i in [100158,100150,100152,100155,100156,100157,100149,100159,100160,100151,100153,100154,100148]:
        nh=nh+1
    elif i in [100093,100111,100171,100173,100178,100183,100075,100029,100172,100170,100097,100176,100179]:
        ws=ws+1
    elif i in [100142,100134,100135,100137,100138,100139,100140,100141,100124,100143,100144,100145,100146,100133,100136,100131,100147]:
        bt=bt+1
    elif i in [100118,100056,100018,100048,100045,100081,100101,100036,100087]:
        ss=ss+1
    elif i in [100128,100054,100099,100049,100051,100078,100080,100109]:
        xi=xi+1
    elif i in [100169,100165,100166,100168,100164,100161,100162,100191,100167]:
        nk=nk+1
    elif i in [100095,100004,100070,100074,100003,100035,100079,100002,100031]:
        wh=wh+1

# %%
for i in dataT4['交寄局號']:
    if i in [100042,100106,100126,100129,100052,100028,100123,100105,100073,100077,100083,100116,100059,100086,100125]:
        sl=sl+1
    elif i in [100050,100061,100047,100021,100010,100011]:
        dt=dt+1
    elif i in [100096,100082,100117,100023,100024,100032,100057,100007,100022,100108,100043,100053,100026,100044,100090,100091]:
        da=da+1
    elif i in [100014,100058,100072,100100,100107,100110,100115,100120,100177,100001,100006,100008,100071,100012,100015,100020,100025,100084,100064,100092,100030,100033,100005,100013,100000,100039]:
        cc=cc+1
    elif i in [100027,100104,100121,100192,100065,100009,100017,100037,100046,100068,100112,100034,100055,100067,100122]:
        cs=cs+1
    elif i in [100158,100150,100152,100155,100156,100157,100149,100159,100160,100151,100153,100154,100148]:
        nh=nh+1
    elif i in [100093,100111,100171,100173,100178,100183,100075,100029,100172,100170,100097,100176,100179]:
        ws=ws+1
    elif i in [100142,100134,100135,100137,100138,100139,100140,100141,100124,100143,100144,100145,100146,100133,100136,100131,100147]:
        bt=bt+1
    elif i in [100118,100056,100018,100048,100045,100081,100101,100036,100087]:
        ss=ss+1
    elif i in [100128,100054,100099,100049,100051,100078,100080,100109]:
        xi=xi+1
    elif i in [100169,100165,100166,100168,100164,100161,100162,100191,100167]:
        nk=nk+1
    elif i in [100095,100004,100070,100074,100003,100035,100079,100002,100031]:
        wh=wh+1

# %%
print('士林=',sl)
print('大同=',dt)
print('大安=',da)
print('中正=',cc)
print('中山=',cs)
print('內湖=',nh)
print('文山=',ws)
print('北投=',bt)
print('松山=',ss)
print('信義=',xi)
print('南港=',nk)
print('萬華=',wh)

# %%
print('士林=',sl//15)
print('大同=',dt//6)
print('大安=',da//16)
print('中正=',cc//24)
print('中山=',cs//15)
print('內湖=',nh//13)
print('文山=',ws//13)
print('北投=',bt//17)
print('松山=',ss//9)
print('信義=',xi//8)
print('南港=',nk//9)
print('萬華=',wh//9)

# %%
print('士林=',(sl/15)//3)
print('大同=',(dt/6)//3)
print('大安=',(da/16)//3)
print('中正=',(cc/24)//3)
print('中山=',(cs/15)//3)
print('內湖=',(nh/13)//3)
print('文山=',(ws/13)//3)
print('北投=',(bt/17)//3)
print('松山=',(ss/9)//3)
print('信義=',(xi/8)//3)
print('南港=',(nk/9)//3)
print('萬華=',(wh/9)//3)
